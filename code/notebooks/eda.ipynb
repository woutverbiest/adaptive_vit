# %% [markdown]
# # EDA

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

from tqdm import tqdm
from glob import glob

import matplotlib.image as mpimg

# %%
img_path_ground_truth = '/project_ghent/woverbie/code/dataset/camera_lidar_semantic/20180807_145028/label/cam_front_center/20180807145028_label_frontcenter_000059298.png'
image_path = '/project_ghent/woverbie/code/dataset/camera_lidar_semantic/20180807_145028/camera/cam_front_center/20180807145028_camera_frontcenter_000059298.png'

img = mpimg.imread(image_path)

plt.imshow(img)
plt.axis('off')
plt.show()

img_gt = mpimg.imread(img_path_ground_truth)

plt.imshow(img_gt)
plt.axis('off')
plt.show()
