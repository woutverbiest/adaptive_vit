# %% [markdown]
# # Installs
#
# ## Dependencies

# %%
# !sudo apt-get update
# !sudo apt-get install g++ ffmpeg libsm6 libxext6 -y

# python dependencies
# !pip install opencv-python
# !pip install ninja 
# !pip install ftfy
# !pip install regex
# !pip install scipy 
# !pip install timm
# !pip install tensorboardX
# !pip install future tensorboard

# reinstalling torch 2.1.2 (for compatibility reasons in mmcv)
# !pip uninstall torch torchvision -y
# !pip uninstall torch torchvision -y
# !pip install torch==2.1.2 torchvision==0.16.2 --index-url https://download.pytorch.org/whl/cu121

# installing latest mmcv-full version that is below 2.0.0 and compatible with current cuda version
# !pip install mmcv-full==1.7.2 -f https://download.openmmlab.com/mmcv/dist/cu121/torch2.1/index.html

# !pip install "mmsegmentation==0.30.0"

# !pip install fvcore
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy InRelease [270 kB]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security/multiverse amd64 Packages [45.2 kB]
# Get:4 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security/restricted amd64 Packages [3527 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# Get:7 http://archive.ubuntu.com/ubuntu jammy/universe amd64 Packages [17.5 MB]
# Get:8 http://security.ubuntu.com/ubuntu jammy-security/universe amd64 Packages [1228 kB]
# Get:9 http://security.ubuntu.com/ubuntu jammy-security/main amd64 Packages [2561 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy/restricted amd64 Packages [164 kB]
# Get:11 http://archive.ubuntu.com/ubuntu jammy/multiverse amd64 Packages [266 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy/main amd64 Packages [1792 kB]
# ...

# %% [markdown]
# ## Model Weights

# %%
# !wget -P ./model/checkpoint/ https://huggingface.co/Akide/SegViTv1/resolve/main/COCOstuff_49.9.pth
# Out:
# --2025-01-26 15:13:26--  https://huggingface.co/Akide/SegViTv1/resolve/main/COCOstuff_49.9.pth
# Resolving huggingface.co (huggingface.co)... 18.239.50.16, 18.239.50.49, 18.239.50.80, ...
# Connecting to huggingface.co (huggingface.co)|18.239.50.16|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# ## Installs for git

# %%
# !sudo apt-get update

# !curl -s https://packagecloud.io/install/repositories/github/git-lfs/script.deb.sh | sudo bash
# !sudo apt-get install git-lfs

# !git-lfs install
